# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")

# %%
data.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary  Address
# 0              Texas  7730337.0      NaN
# 1          Marquette  6796117.0      NaN
# 2  Boston University        NaN      NaN
# 3      Georgia State  1148640.0      NaN
# 4                NaN  5000000.0      NaN

# %%
data['Address'] = np.nan

# %%
xx, yy = np.meshgrid(np.linspace(-1, 1, 128), np.linspace(-1, 1, 128))

# %%
def Gaussian2D(xx, yy):
    return 1.*np.exp(-(xx**2+yy**2))

zz = Gaussian2D(xx, yy)+.05*np.random.rand(128, 128)

# %%
plt.imshow(zz, vmax=1)

# %%
run_data = pd.Series({'var1': 1, 'a': 2})
run_data
# Out:
# var1    1
# a       2
# dtype: int64

# %%
result = pd.Series({'z': 0, 'a': 1})
result
# Out:
# z    0
# a    1
# dtype: int64

# %%
result['z'] = 1
result['a'] = 2
result.keys()
# Out:
# Index(['z', 'a'], dtype='object')

# %%
df = pd.DataFrame()

def append_series(df, series):
    for _key in series.keys():
        df.loc[0, _key] = series[_key]
    
append_series(df, result)
append_series(df, result2)
df
# Out:
#      z    a    b    0
# 0  1.0  2.0  3.0  4.0

# %%
result2 = pd.Series({'b': 3, '0': 4})

# %%
result.name

# %%
df.iloc[0]
# Out:
# z    1.0
# a    2.0
# b    3.0
# 0    4.0
# Name: 0, dtype: float64
